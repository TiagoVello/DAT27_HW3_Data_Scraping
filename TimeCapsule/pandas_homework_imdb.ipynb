# %%
'''
Pandas Homework with IMDb data
'''

# %%
'''
BASIC LEVEL
'''
# Out:
# '\nBASIC LEVEL\n'

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# read in 'imdb_1000.csv' and store it in a DataFrame named movies
imdb_1000_data_url = r'C:/Data_Science/Git/DAT27_HW2_Pandas/data/imdb_1000.csv'
movies = pd.read_csv(imdb_1000_data_url)
movies.head(60)
# Out:
#     star_rating                                              title  \
# 0           9.3                           The Shawshank Redemption
# 1           9.2                                      The Godfather
# 2           9.1                             The Godfather: Part II
# 3           9.0                                    The Dark Knight
# 4           8.9                                       Pulp Fiction
# 5           8.9                                       12 Angry Men
# 6           8.9                     The Good, the Bad and the Ugly
# 7           8.9      The Lord of the Rings: The Return of the King
# 8           8.9                                   Schindler's List
# 9           8.9                                         Fight Club
# 10          8.8  The Lord of the Rings: The Fellowship of the Ring
# 11          8.8                                          Inception
# 12          8.8     Star Wars: Episode V - The Empire Strikes Back
# ...

# %%
# check the number of rows and columns
movies.shape
# Out:
# (979, 6)

# %%
# check the data type of each column
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# calculate the average movie duration
movies.duration.mean()
# Out:
# 120.97957099080695

# %%
# sort the DataFrame by duration to find the shortest and longest movies
movies.sort_values('duration').head()
movies.sort_values('duration').tail()
# Out:
#      star_rating                              title content_rating      genre  \
# 445          7.9               The Ten Commandments       APPROVED  Adventure
# 142          8.3  Lagaan: Once Upon a Time in India             PG  Adventure
# 78           8.4        Once Upon a Time in America              R      Crime
# 157          8.2                 Gone with the Wind              G      Drama
# 476          7.8                             Hamlet          PG-13      Drama
#
#      duration                                        actors_list
# 445       220  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 142       224  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 78        229  [u'Robert De Niro', u'James Woods', u'Elizabet...
# 157       238  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476       242  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %%
# create a histogram of duration, choosing an "appropriate" number of bins
movies.hist(column = 'duration',bins = 30)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000013308CF6E10>]],
#       dtype=object)

# %%
# use a box plot to display that same data
movies.boxplot(column = 'duration')

# %%
'''
INTERMEDIATE LEVEL
'''

# %%
# count how many movies have each of the content ratings
movies.groupby(by='content_rating')['title'].count()
# Out:
# content_rating
# APPROVED      47
# G             32
# GP             3
# NC-17          7
# NOT RATED     65
# PASSED         7
# PG           123
# PG-13        189
# R            460
# TV-MA          1
# UNRATED       38
# X              4
# Name: title, dtype: int64

# %%
# use a visualization to display that same data, including a title and x and y labels
movies.groupby(by='content_rating')['title'].count().plot.bar(title='Movies content rating',y='Number of Movies',x='Content Rating')

# %%
# convert the following content ratings to "UNRATED": NOT RATED, APPROVED, PASSED, GP
movies.content_rating.replace(['NOT RATED', 'APPROVED', 'PASSED', 'GP'], 'UNRATED')
# Out:
# 0            R
# 1            R
# 2            R
# 3        PG-13
# 4            R
# 5      UNRATED
# 6      UNRATED
# 7        PG-13
# 8            R
# 9            R
# 10       PG-13
# 11       PG-13
# 12          PG
# 13       PG-13
# 14       PG-13
# 15       PG-13
# 16           R
# 17     UNRATED
# 18           R
# 19          PG
# 20           R
# 21           R
# 22     UNRATED
# 23           R
# 24           R
# 25       PG-13
# 26       PG-13
# 27           R
# 28           R
# 29     UNRATED
#         ...
# 949         PG
# 950          R
# 951          R
# 952          R
# 953         PG
# 954      PG-13
# 955          R
# 956         PG
# 957          R
# 958      PG-13
# 959          R
# 960      PG-13
# 961          R
# 962         PG
# 963          R
# 964      PG-13
# 965      PG-13
# 966      PG-13
# 967          R
# 968          R
# 969          R
# 970          R
# 971          R
# 972      NC-17
# 973      PG-13
# 974         PG
# 975         PG
# 976      PG-13
# ...

# %%
# convert the following content ratings to "NC-17": X, TV-MA
movies.content_rating.replace(['X', 'TV-MA'], 'NC-17')
# Out:
# 0              R
# 1              R
# 2              R
# 3          PG-13
# 4              R
# 5      NOT RATED
# 6      NOT RATED
# 7          PG-13
# 8              R
# 9              R
# 10         PG-13
# 11         PG-13
# 12            PG
# 13         PG-13
# 14         PG-13
# 15         PG-13
# 16             R
# 17       UNRATED
# 18             R
# 19            PG
# 20             R
# 21             R
# 22      APPROVED
# 23             R
# 24             R
# 25         PG-13
# 26         PG-13
# 27             R
# 28             R
# 29        PASSED
#          ...
# 949           PG
# 950            R
# 951            R
# 952            R
# 953           PG
# 954        PG-13
# 955            R
# 956           PG
# 957            R
# 958        PG-13
# 959            R
# 960        PG-13
# 961            R
# 962           PG
# 963            R
# 964        PG-13
# 965        PG-13
# 966        PG-13
# 967            R
# 968            R
# 969            R
# ...

# %%
# count the number of missing values in each column
movies.isnull().sum()
# Out:
# star_rating       0
# title             0
# content_rating    3
# genre             0
# duration          0
# actors_list       0
# dtype: int64

# %%
# if there are missing values: examine them, then fill them in with "reasonable" values
movies[movies.isnull().any(axis=1)]
# Out:
#      star_rating                               title content_rating  \
# 187          8.2  Butch Cassidy and the Sundance Kid            NaN
# 649          7.7                   Where Eagles Dare            NaN
# 936          7.4                           True Grit            NaN
#
#          genre  duration                                        actors_list
# 187  Biography       110  [u'Paul Newman', u'Robert Redford', u'Katharin...
# 649     Action       158  [u'Richard Burton', u'Clint Eastwood', u'Mary ...
# 936  Adventure       128    [u'John Wayne', u'Kim Darby', u'Glen Campbell']

# %%
# calculate the average star rating for movies 2 hours or longer,
# and compare that with the average star rating for movies shorter than 2 hours
movies[movies.duration > 120]['star_rating'].mean()
movies[movies.duration < 120]['star_rating'].mean()
# Out:
# 7.838666666666657

# %%
# use a visualization to detect whether there is a relationship between duration and star rating
movies.plot.scatter(x = 'duration', y = 'star_rating')

# %%
# calculate the average duration for each genre
movies.groupby(by = 'genre')['duration'].mean()
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
'''
ADVANCED LEVEL
'''

# %%
# visualize the relationship between content rating and duration
movies.groupby(by = 'content_rating')['duration'].mean().plot.bar()

# %%
# determine the top rated movie (by star rating) for each genre
movies.groupby(by = 'genre')['star_rating','title'].max()
# Out:
#            star_rating                                title
# genre
# Action             9.0                              Yojimbo
# Adventure          8.9                            True Grit
# Animation          8.6                       Wreck-It Ralph
# Biography          8.9                        Walk the Line
# Comedy             8.6                           Zombieland
# Crime              9.3                               Zodiac
# Drama              8.9                                 Zulu
# Family             7.9  Willy Wonka & the Chocolate Factory
# Fantasy            7.7            The City of Lost Children
# Film-Noir          8.3                        The Third Man
# History            8.0                  Battleship Potemkin
# Horror             8.6                                [Rec]
# Mystery            8.6                              Vertigo
# Sci-Fi             8.2        The Day the Earth Stood Still
# Thriller           8.0            The Man Who Knew Too Much
# ...

# %%
# check if there are multiple movies with the same title, and if so, determine if they are actually duplicates
movies[movies.duplicated('title', keep=False)]
print ('They were not duplicated. The data is for diferent movies')
# Out:
# They were not duplicated. The data is for diferent movies

# %%
# calculate the average star rating for each genre, but only include genres with at least 10 movies
movies.groupby(by = 'genre').mean()[movies.groupby(by = 'genre').count() > 10].dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-176-0a65a6913cce> in <module>()
#       1 # calculate the average star rating for each genre, but only include genres with at least 10 movies
# ----> 2 movies.groupby(by = 'genre').drop('duration').mean()[movies.groupby(by = 'genre').count() > 10].dropna()
#       3
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in __getattr__(self, attr)
#     671             return self[attr]
#     672         if hasattr(self.obj, attr):
# --> 673             return self._make_wrapper(attr)
#     674
#     675         raise AttributeError("%r object has no attribute %r" %
#
# ~\Anaconda3\lib\site-packages\pandas\core\groupby.py in _make_wrapper(self, name)
#     685                    "using the 'apply' method".format(kind, name,
#     686                                                      type(self).__name__))
# ...

# %%
# option 1: manually create a list of relevant genres, then filter using that list
relevant_genres = ['Action','Comedy','Sci-Fi', 'Horror']
# Out:
# Object `.count` not found.

# %%
# option 2: automatically create a list of relevant genres by saving the value_counts and then filtering

# %%
# option 3: calculate the average star rating for all genres, then filter using a boolean Series
movies.groupby(by = 'genre').mean()[movies.groupby(by = 'genre').count() > 10].dropna()
# Out:
#            star_rating    duration
# genre
# Action        7.884559  126.485294
# Adventure     7.933333  134.840000
# Animation     7.914516   96.596774
# Biography     7.862338  131.844156
# Comedy        7.822436  107.602564
# Crime         7.916935  122.298387
# Drama         7.902518  126.539568
# Horror        7.806897  102.517241
# Mystery       7.975000  115.625000

# %%
# option 4: aggregate by count and mean, then filter using the count
all_actors = pd.DataFrame()
??all_actors.append()

# %%
'''
BONUS
'''

# %%
best_actor = 'Error'
all_actors = pd.DataFrame()
# Figure out something "interesting" using the actors data!
for i in range(len(movies['actors_list'])
    for j in range(len(movies['actors_list'][i]))
        all_actors.append(movies['actors_list'][i][j]:movies['title'][i]}
print(all_actors)
# Out:
#   File "<ipython-input-203-cda9ac240b70>", line 6
#     all_actors.append(movies['actors_list'][i][j]:movies['title'][i]}
#              ^
# SyntaxError: invalid syntax
